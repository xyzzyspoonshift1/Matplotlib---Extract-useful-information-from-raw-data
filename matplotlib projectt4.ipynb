# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **religious events or traditions** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **religious events or traditions**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **religious events or traditions**?  For this category you might consider calendar events, demographic data about religion in the region and neighboring regions, participation in religious events, or how religious events relate to political events, social movements, or historical events.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

df = pd.read_excel("traditional events michigan.xlsx")
df_active = df[df['Status'] == 'Active']
df_inactive = df[df['Status'] == 'Inactive']
df
# Out:
#                                                  Name  \
# 0                                           Alpenfest
# 1                                 Ann Arbor Art Fairs
# 2                   Ann Arbor Blues and Jazz Festival
# 3                             Ann Arbor Film Festival
# 4                           Ann Arbor Summer Festival
# 5                                            ArtPrize
# 6                                Arts, Beats and Eats
# 7                                  Baby Food Festival
# 8                                  Back to the Bricks
# 9                         Bay City Fireworks Festival
# 10                       Beaver Island Music Festival
# 11                                Calhoun County Fair
# 12                         Capital City Film Festival
# 13                           Celebration on the Grand
# 14                          Cheeseburger in Caseville
# 15                               Coast Guard Festival
# 16                       Common Ground Music Festival
# 17                                  Concert of Colors
# 18                                   Curwood Festival
# 19                                 Dally in the Alley
# 20                                    Danish Festival
# 21                       Dearborn Homecoming Festival
# 22                  Detroit Electronic Music Festival
# 23                       Detroit Festival of the Arts
# 24                Detroit International Jazz Festival
# 25                                 Detroit River Days
# 26        Detroit Windsor International Film Festival
# 27                         East Lansing Film Festival
# 28                           Electric Forest Festival
# 29                   En Gedi Christian Music Festival
# ..                                                ...
# 52                                    Mo Pop Festival
# 53                                 Monroe County Fair
# 54                                   Motor City Pride
# 55                           National Cherry Festival
# 56                       National Strawberry Festival
# 57                            National Trout Festival
# 58                                         Noel Night
# 59                                 Old Town BluesFest
# 60                       Pine Mountain Music Festival
# 61                 Porcupine Mountains Music Festival
# 62                              Posen Potato Festival
# 63                                       Pulaski Days
# 64                                   Racin and Rockin
# 65                     South Haven Blueberry Festival
# 66                           Stars & Stripes Festival
# 67                                       Sterlingfest
# 68  Things That Go Bump In The Night Film Fest (Bu...
# 69                    Threadbare Mitten Film Festival
# 70                        Traverse City Film Festival
# 71           Traverse City Microbrew & Music Festival
# 72                                Tulip Time Festival
# 73                     Unity Christian Music Festival
# 74                         Upper Peninsula State Fair
# 75                                  Venetian Festival
# 76                           Waterfront Film Festival
# 77                                  Wayne County Fair
# 78                           Wheatland Music Festival
# 79                                           Youmacon
# 80                        Ypsilanti Heritage Festival
# 81                                   90s Flannel Fest
#
#                    Start date (approximate)                        City  \
# 0                            July, 3rd week                     Gaylord
# 1                            July, 3rd week                   Ann Arbor
# 2                                       NaN                   Ann Arbor
# 3                           March, 4th week                   Ann Arbor
# 4           June, 2nd week - July, 1st week                   Ann Arbor
# 5   September, 4th week - October, 2nd week                Grand Rapids
# 6                          August, 4th week                   Royal Oak
# 7                            July, 3rd week                     Fremont
# 8                          August, 2nd week                       Flint
# 9                                 July, 4th                    Bay City
# 10                           July, 3rd week               Beaver Island
# 11                         August, 2nd week                    Marshall
# 12                          April, 2nd week                     Lansing
# 13                                July, 4th                Grand Rapids
# 14              August, 2nd week - 3rd week                   Caseville
# 15                           July, 4th week                 Grand Haven
# 16                           July, 2nd week                     Lansing
# 17                           July, 2nd week                     Detroit
# 18                           June, 1st week                      Owosso
# 19                      September, 1st week                     Detroit
# 20                         August, 2nd week                  Greenville
# 21                         August, 1st week                    Dearborn
# 22                            May, 4th week                     Detroit
# 23                                      NaN                     Detroit
# 24                         August, 4th week                     Detroit
# 25                           June, 4th week                     Detroit
# 26                                      NaN  Detroit / Windsor, Ontario
# 27                       November, 1st week                East Lansing
# 28                           June, 4th week                    Rothbury
# 29                           July, 4th week                    Leonidas
# ..                                      ...                         ...
# 52                           July, 4th week                     Detroit
# 53       July, last week - August, 1st week                      Monroe
# 54                           June, 2nd week                     Detroit
# 55                           July, 2nd week               Traverse City
# 56                           June, 3rd week                  Belleville
# 57                          April, 4th week                    Kalkaska
# 58                       December, 1st week                     Detroit
# 59                      September, 3rd week                     Lansing
# 60        July, 4th week - August, 1st week     western Upper Peninsula
# 61                         August, 4th week                   Ontonagon
# 62                      September, 1st week                       Posen
# 63                        October, 1st week                Grand Rapids
# 64                                      NaN                  Springport
# 65                         August, 2nd week                 South Haven
# 66                           June, 4th week            Sterling Heights
# 67                           July, 4th week            Sterling Heights
# 68                                  October                    Bay City
# 69                             June 23 & 24                   Charlotte
# 70                           July, 4th week               Traverse City
# 71                         August, 2nd week               Traverse City
# 72                            May, 1st week                     Holland
# 73                         August, 2nd week                    Muskegon
# 74                         August, 3rd week                    Escanaba
# 75                           July, 3rd week                  Charlevoix
# 76                           June, 2nd week                 South Haven
# 77                         August, 2nd week                  Belleville
# 78                      September, 1st week                       Remus
# 79                       November, 1st week                     Detroit
# 80                         August, 3rd week                   Ypsilanti
# 81                      August, 3rd weekend              Saginaw County
#
#                 Type    Status
# 0             Ethnic    Active
# 1                Art    Active
# 2              Music  Inactive
# 3               Film    Active
# 4             Summer    Active
# 5                Art    Active
# 6             Summer    Active
# 7             Summer    Active
# 8                Car    Active
# 9            Holiday    Active
# 10             Music    Active
# 11              Fair    Active
# 12              Film    Active
# 13           Holiday    Active
# 14            Summer    Active
# 15             Honor    Active
# 16             Music    Active
# 17             Music    Active
# 18          Literary    Active
# 19         Community    Active
# 20            Ethnic    Active
# 21            Summer    Active
# 22             Music    Active
# 23               Art  Inactive
# 24             Music    Active
# 25            Summer    Active
# 26              Film  Inactive
# 27              Film    Active
# 28             Music    Active
# 29             Music    Active
# ..               ...       ...
# 52             Music    Active
# 53              Fair    Active
# 54              LGBT    Active
# 55              Food    Active
# 56              Food    Active
# 57              Fish    Active
# 58           Holiday    Active
# 59             Music    Active
# 60             Music    Active
# 61             Music    Active
# 62              Food    Active
# 63            Ethnic    Active
# 64             Music  Inactive
# 65              Food    Active
# 66             Music    Active
# 67            Summer    Active
# 68              Film    Active
# 69              Film    Active
# 70              Film    Active
# 71  Music&Craft Beer  Inactive
# 72            Flower    Active
# 73             Music    Active
# 74              Fair    Active
# 75            Summer    Active
# 76              Film    Active
# 77              Fair    Active
# 78             Music    Active
# 79             Anime    Active
# 80          Heritage    Active
# 81             Music    Active
#
# [82 rows x 5 columns]

# %%
plt.bar([1,2],[len(df_active),len(df_inactive)],width = 0.5, align = 'center')
plt.plot([0.75,2.25],[len(df_active),len(df_active)],'--',color='green')
plt.plot([0.75,2.25],[len(df_inactive),len(df_inactive)],'--',color ='red')
plt.legend([len(df_active),len(df_inactive)])
plt.ylabel("Number of events")
plt.xticks([1,2],['Active','Inactive'])
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
df = df_active
df = df.dropna()
def convert(s):
    new_list=[]
    for i in range(len(s)):
        if (list(s)[i] == ','):
            break
        new_list.append(list(s)[i])
    month = ''.join(new_list)
    return month
#print(len(df))
month_list = []
for i in range(len(df)):
    month_list.append(convert(df['Start date (approximate)'].iloc[i]))
month_list[-13] = 'July'
df['month'] = month_list
x = np.arange(1,13)
x = list(x)
monthnames = ['January','February','March','April','May','June','July','August','September','October','November','December']
#print(monthnames)
plt.figure();
i=1
for month in monthnames:
    length = len(df[df['month'] == month])
    plt.bar(i,length,edgecolor='black')
    i=i+1
plt.xticks(x,monthnames,rotation = 90)
plt.ylabel('Number of events')
plt.title('Number of active events in different months')
plt.yticks(np.arange(0,26,2))
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
